# %%
def baric_corr(carpeta):
    from astropy.io import fits
    from astropy.time import Time
    from astropy.coordinates import SkyCoord, EarthLocation
    import astropy.units as u
    from astropy.constants import c
    import numpy as np
    import glob 
    import os
    
    patron = os.path.join(carpeta, '*05_AIR_modificado.fits')#Gran*-star*_sum_m*_fsr1.05_AIR_modificado.fits
    archivos= glob.glob(patron)

    if not archivos:
        print(f"no se encontraron archivos en: {carpeta}")
        return
    print(f'se encontraron {len(archivos)} archivos')
    v_s= []
    for archivo in archivos:
        print(f'procesando {archivo}')
        # leer el fits
        hdul = fits.open(archivo)
        hdr = hdul[0].header
        flux = hdul[0].data

        ra = hdr['RA']
        dec = hdr['DEC']
        date = hdr['DATE-OBS']
        obj = SkyCoord(ra, dec, unit=(u.hourangle, u.deg))
        location = EarthLocation.of_site("La Silla Observatory")
        location = location.to_geodetic()
        t = Time(date, format = 'mjd', location=location)
        barycorr = obj.radial_velocity_correction(obstime=t)
        v_bc = barycorr.to(u.km/u.s).value
        v_s.append(v_bc)
    return(np.median(v_s))

# %%
st1 = baric_corr('/home/nacho/molecfit_test/mis_outputs_star1/')
st3 = baric_corr('/home/nacho/molecfit_test/mis_outputs_star3/')
st4 = baric_corr('/home/nacho/molecfit_test/mis_outputs_star4/')
st7 = baric_corr('/home/nacho/molecfit_test/mis_outputs_star7/')
st8 = baric_corr('/home/nacho/molecfit_test/mis_outputs_star8/')
st9 = baric_corr('/home/nacho/molecfit_test/mis_outputs_star9/')
# Out:
# se encontraron 13 archivos
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.fits
# se encontraron 13 archivos
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.fits
# se encontraron 13 archivos
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m43_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m44_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m45_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m46_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m47_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m48_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m51_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m52_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m53_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m54_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m55_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m56_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m57_fsr1.05_AIR_modificado.fits
# se encontraron 13 archivos
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m43_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m44_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m45_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m46_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m47_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m48_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m51_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m52_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m53_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m54_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m55_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m56_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m57_fsr1.05_AIR_modificado.fits
# se encontraron 13 archivos
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m43_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m44_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m45_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m46_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m47_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m48_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m51_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m52_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m53_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m54_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m55_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m56_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m57_fsr1.05_AIR_modificado.fits
# se encontraron 13 archivos
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m43_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m44_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m45_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m46_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m47_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m48_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m51_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m52_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m53_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m54_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m55_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m56_fsr1.05_AIR_modificado.fits
# procesando /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m57_fsr1.05_AIR_modificado.fits

# %% [markdown]
# # para pasar de vacio a aire

# %%
def vac_to_air(wavelength_vac):
    import numpy as np
    wl_vac = np.atleast_1d(wavelength_vac)
    
    sigma2 = (1e4 / wl_vac)**2
    # indice de refracción del aire (n-1) * 10^8
    # n_minus_1 = 6432.8 + 2949810.0 / (146.0 - sigma2) + 25540.0 / (41.0 - sigma2) # edlen 1953
    # n_minus_1 = 8343.05 + 2406294.0 / (130.0 - sigma2) + 15999 / (38.9 - sigma2) # birch 1993
    n_minus_1 = 8342.54 + 2406147 / (130 - sigma2) + 15998 / (38.9 - sigma2) # vald
    n_minus_1 *= 1e-8
    
    n = 1.0 + n_minus_1
    
    # Conversión de vacío a aire
    wl_air = wl_vac / n
    
    print(f"el indice de refraccion es:{n} ")
    return wl_air
def vacuum_a_air(ruta_carpeta):
    from astropy.io import fits
    from shutil import copyfile
    import os 
    import glob
    
    patron = os.path.join(ruta_carpeta, '*par_tac.fits')
    archivos = glob.glob(patron)
    
    if not archivos:
        print(f"No se encontraron archivos que terminen en 'par_tac.fits' en la carpeta: {ruta_carpeta}")
        return
    
    print(f"Se encontraron {len(archivos)} archivos para procesar:")
    for archivo in archivos:
        print(f"  - {os.path.basename(archivo)}")
    
    for archivo in archivos:
        print(f"\nProcesando: {archivo}")
        
        # Copia de seguridad
        backup = archivo.replace('.fits', '_backup_vacuum.fits')
        if not os.path.exists(backup):
            copyfile(archivo, backup)
            print(f"  Copia de seguridad creada: {backup}")
        else:
            print(f"  Copia de seguridad ya existe: {backup}")
        
        
        with fits.open(backup, mode='update') as hdul:
            datos = hdul[1].data
            long_onda = datos['LAMBDA']
            
            # Convertir y sobreescribir
            datos['LAMBDA'] = vac_to_air(long_onda)
            
            # Con mode='update', flush() guarda los cambios
            hdul.flush()
        
        print(f"  ¡Listo! {backup} ahora tiene longitudes de onda en AIRE")
    
    print(f"\nProcesamiento completado. Total de archivos procesados: {len(archivos)}")

# %%
#archivos = "/home/nacho/molecfit_test/mis_outputs_star1/"
#vacuum_a_air(archivos)
archivos3 = "/home/nacho/molecfit_test/mis_outputs_star3/"
vacuum_a_air(archivos3)
archivos4 = "/home/nacho/molecfit_test/mis_outputs_star4/"
vacuum_a_air(archivos4)
archivos7 = "/home/nacho/molecfit_test/mis_outputs_star7/"
vacuum_a_air(archivos7)
archivos8 = "/home/nacho/molecfit_test/mis_outputs_star8/"
vacuum_a_air(archivos8)
archivos9 = "/home/nacho/molecfit_test/mis_outputs_star9/"
vacuum_a_air(archivos9)
# Out:
# Se encontraron 13 archivos para procesar:
#   - Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008342 1.00008342 1.00008342 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesamiento completado. Total de archivos procesados: 13
# Se encontraron 13 archivos para procesar:
#   - Gran1-star4_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star4_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008342 1.00008342 1.00008342 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesamiento completado. Total de archivos procesados: 13
# Se encontraron 13 archivos para procesar:
#   - Gran1-star7_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star7_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008342 1.00008342 1.00008342 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesamiento completado. Total de archivos procesados: 13
# Se encontraron 13 archivos para procesar:
#   - Gran01-star8_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran01-star8_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008342 1.00008342 1.00008342 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesamiento completado. Total de archivos procesados: 13
# Se encontraron 13 archivos para procesar:
#   - Gran1-star9_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   - Gran1-star9_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m43_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008342 1.00008342 1.00008342 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m44_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008342 1.00008342 1.00008342]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m45_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m46_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m47_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m48_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m51_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m52_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m53_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m54_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m55_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m56_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesando: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m57_fsr1.05_AIR_modificado.par_tac.fits
#   Copia de seguridad ya existe: /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits
# el indice de refraccion es:[1.00008343 1.00008343 1.00008343 ... 1.00008343 1.00008343 1.00008343]
#   ¡Listo! /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum.fits ahora tiene longitudes de onda en AIRE
#
# Procesamiento completado. Total de archivos procesados: 13

# %% [markdown]
# # aplicar CCF

# %%
def cross_corr_apli(carpeta):
    """esta funcion se encarga de hacer el CCF y aplicar también la correccion por velocidad baricentrica
    input: 
    carpeta: corresponde a la carpeta en donde se encuentran nuestros archivos fits, ya sean los archivos
    fits de calctrans o los archivos fits que necesita la funcon baric_corr
    
    outputs: entrega un .dat con el CCF ademas de graficos png para observar el fit"""
    import glob
    import os
    import re
    import subprocess

    # carpeta 
    grillas = "/home/nacho/molecfit_test/winered_R28k_airGrid/" # grilla en aire 
    #grillas = "/home/nacho/molecfit_test/winered_R28K_vacGrid/" # grilla en vacio 

    # buscar los ordenes
    archivos = sorted(glob.glob(os.path.join(carpeta, "**", "*AIR_modificado.par_tac.fits"), recursive=True)) #par_tac_backup_vacuum / par_tac.fits /AIR.fits
    
    if not archivos:
        print(" No se encontraron archivos _par_tac.fits.")
        return
    ordenes_validos = []
    for ruta in archivos:
        match = re.search(r'_m(\d+)_', ruta)
        if match:
            orden = int(match.group(1))
            ordenes_validos.append((orden, ruta))
    # ordenar por el numero de orden 
    ordenes_validos.sort(key=lambda x: x[0])

    for orden, ruta in ordenes_validos:
        print(f"\n Procesando orden {orden}...")
        cmd = [
            "python3", "rvcorr_fitsTableSpec.py",
            ruta,
            grillas,
            "--vmin", "50",
            "--vmax", "150",
            "-n"
        ]
        try:
            subprocess.run(cmd, check=True)
            print(f"Orden {orden} procesado con éxito.")
        except subprocess.CalledProcessError:
            print(f" Error procesando orden {orden}.")

# %% [markdown]
# # correr solo un espectro en caso de

# %%
def solo_1_espectro(espectro):
    import glob
    import os
    import re
    import subprocess
    grillas = grillas = "/home/nacho/molecfit_test/winered_R28K_vacGrid/"
    match = re.search(r'_m(\d+)_', espectro)
    if match:
        orden= int(match.group(1))
        print(f'leyendo orden {orden }')
    cmd = [
            "python3", "rvcorr_fitsTableSpec.py",
            espectro,
            grillas,
            "--vmin", "100",
            "--vmax", "110",
            "-n"
        ]
    try:
        subprocess.run(cmd, check=True)
        print(f"Orden {orden} procesado con éxito.")
    except subprocess.CalledProcessError:
        print(f" Error procesando orden {orden}.")

# %%
#estrella 1 
carpeta = "/home/nacho/molecfit_test/mis_outputs_star1//"
#carpeta = "/home/nacho/molecfit_test/mis_outputsVAC_star1/"
cross_corr_apli(carpeta)
# Out:
#  Procesando orden 43...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  113.50
# [Info] Best template chisquare:  0.0024472380802688055
# [Info] ccf Vobs:  113.675
# [Info] Final Vobs:  113.664
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 43 procesado con éxito.
#
#  Procesando orden 44...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  114.50
# [Info] Best template chisquare:  0.0017225748564734021
# [Info] ccf Vobs:  113.325
# [Info] Final Vobs:  113.328
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 44 procesado con éxito.
#
#  Procesando orden 45...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  111.00
# [Info] Best template chisquare:  0.005457582581656986
# [Info] ccf Vobs:  112.100
# [Info] Final Vobs:  112.105
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 45 procesado con éxito.
#
#  Procesando orden 46...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  115.00
# [Info] Best template chisquare:  0.0011552249539543704
# [Info] ccf Vobs:  113.900
# [Info] Final Vobs:  114.381
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 46 procesado con éxito.
#
#  Procesando orden 47...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  113.00
# [Info] Best template chisquare:  0.0011063213609222669
# [Info] ccf Vobs:  112.775
# [Info] Final Vobs:  112.784
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 47 procesado con éxito.
#
#  Procesando orden 48...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  113.50
# [Info] Best template chisquare:  0.030282745942060336
# [Info] ccf Vobs:  113.700
# [Info] Final Vobs:  113.697
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 48 procesado con éxito.
#
#  Procesando orden 51...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  112.50
# [Info] Best template chisquare:  0.003601118274986084
# [Info] ccf Vobs:  112.000
# [Info] Final Vobs:  111.999
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 51 procesado con éxito.
#
#  Procesando orden 52...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  112.50
# [Info] Best template chisquare:  0.0016087251494128216
# [Info] ccf Vobs:  112.475
# [Info] Final Vobs:  112.485
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 52 procesado con éxito.
#
#  Procesando orden 53...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  112.50
# [Info] Best template chisquare:  0.0009701308086951262
# [Info] ccf Vobs:  112.925
# [Info] Final Vobs:  112.935
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 53 procesado con éxito.
#
#  Procesando orden 54...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  113.00
# [Info] Best template chisquare:  0.0012862743816642794
# [Info] ccf Vobs:  113.050
# [Info] Final Vobs:  113.049
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 54 procesado con éxito.
#
#  Procesando orden 55...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  111.00
# [Info] Best template chisquare:  0.0012418899696502205
# [Info] ccf Vobs:  111.800
# [Info] Final Vobs:  111.790
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 55 procesado con éxito.
#
#  Procesando orden 56...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  110.50
# [Info] Best template chisquare:  0.0016998638776397673
# [Info] ccf Vobs:  111.975
# [Info] Final Vobs:  111.396
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 56 procesado con éxito.
#
#  Procesando orden 57...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  112.00
# [Info] Best template chisquare:  0.0041712935785209165
# [Info] ccf Vobs:  113.625
# [Info] Final Vobs:  113.616
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star1/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 57 procesado con éxito.

# %%
#estrella 3 
carpeta = "/home/nacho/molecfit_test/mis_outputs_star3/"
#carpeta = "/home/nacho/molecfit_test/ordenes_star3/"
#vacuum_a_air(carpeta)
#carpeta = "/home/nacho/molecfit_test/mis_outputsVAC_star3/"
cross_corr_apli(carpeta)
# Out:
#  Procesando orden 43...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  116.00
# [Info] Best template chisquare:  0.002167227966764664
# [Info] ccf Vobs:  115.975
# [Info] Final Vobs:  115.675
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 43 procesado con éxito.
#
#  Procesando orden 44...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  114.50
# [Info] Best template chisquare:  0.001299391750101895
# [Info] ccf Vobs:  115.700
# [Info] Final Vobs:  114.653
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 44 procesado con éxito.
#
#  Procesando orden 45...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  114.50
# [Info] Best template chisquare:  0.0009174221297902095
# [Info] ccf Vobs:  114.625
# [Info] Final Vobs:  114.621
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 45 procesado con éxito.
#
#  Procesando orden 46...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  117.00
# [Info] Best template chisquare:  0.0006994586728574858
# [Info] ccf Vobs:  115.925
# [Info] Final Vobs:  115.934
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 46 procesado con éxito.
#
#  Procesando orden 47...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  114.50
# [Info] Best template chisquare:  0.0020586990865030714
# [Info] ccf Vobs:  114.900
# [Info] Final Vobs:  114.889
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 47 procesado con éxito.
#
#  Procesando orden 48...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  115.00
# [Info] Best template chisquare:  0.0013824285049874546
# [Info] ccf Vobs:  114.950
# [Info] Final Vobs:  114.456
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 48 procesado con éxito.
#
#  Procesando orden 51...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  114.00
# [Info] Best template chisquare:  0.008274286052227653
# [Info] ccf Vobs:  114.300
# [Info] Final Vobs:  114.292
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 51 procesado con éxito.
#
#  Procesando orden 52...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  115.50
# [Info] Best template chisquare:  0.0013456332628937297
# [Info] ccf Vobs:  114.625
# [Info] Final Vobs:  114.631
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 52 procesado con éxito.
#
#  Procesando orden 53...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  114.00
# [Info] Best template chisquare:  0.006174367224147156
# [Info] ccf Vobs:  114.375
# [Info] Final Vobs:  114.591
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 53 procesado con éxito.
#
#  Procesando orden 54...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  114.50
# [Info] Best template chisquare:  0.0005194953940152731
# [Info] ccf Vobs:  114.525
# [Info] Final Vobs:  114.685
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 54 procesado con éxito.
#
#  Procesando orden 55...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  114.50
# [Info] Best template chisquare:  0.0006349166338629764
# [Info] ccf Vobs:  114.750
# [Info] Final Vobs:  114.758
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 55 procesado con éxito.
#
#  Procesando orden 56...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  113.50
# [Info] Best template chisquare:  0.0008218945223311037
# [Info] ccf Vobs:  113.500
# [Info] Final Vobs:  113.488
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 56 procesado con éxito.
#
#  Procesando orden 57...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  115.00
# [Info] Best template chisquare:  0.003083059373014728
# [Info] ccf Vobs:  115.100
# [Info] Final Vobs:  114.076
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star3/Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 57 procesado con éxito.

# %%
#estrella 4
#carpeta = "/home/nacho/molecfit_test/ordenes_star4/"
carpeta = "/home/nacho/molecfit_test/mis_outputs_star4/"
#carpeta = "/home/nacho/molecfit_test/mis_outputsVAC_star4/"
#vacuum_a_air(carpeta)
cross_corr_apli(carpeta)
# Out:
#  Procesando orden 43...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  104.50
# [Info] Best template chisquare:  0.0015521638160835222
# [Info] ccf Vobs:  104.000
# [Info] Final Vobs:  104.000
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m43_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 43 procesado con éxito.
#
#  Procesando orden 44...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  104.50
# [Info] Best template chisquare:  0.0012858612691967063
# [Info] ccf Vobs:  104.700
# [Info] Final Vobs:  104.695
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m44_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 44 procesado con éxito.
#
#  Procesando orden 45...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  104.50
# [Info] Best template chisquare:  0.0009361207395238933
# [Info] ccf Vobs:  104.425
# [Info] Final Vobs:  104.429
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m45_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 45 procesado con éxito.
#
#  Procesando orden 46...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  105.50
# [Info] Best template chisquare:  0.00124814085006977
# [Info] ccf Vobs:  104.600
# [Info] Final Vobs:  104.221
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m46_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 46 procesado con éxito.
#
#  Procesando orden 47...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.50
# [Info] Best template chisquare:  0.000991620564402898
# [Info] ccf Vobs:  103.325
# [Info] Final Vobs:  103.335
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m47_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 47 procesado con éxito.
#
#  Procesando orden 48...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  104.00
# [Info] Best template chisquare:  0.0012160603044768232
# [Info] ccf Vobs:  103.950
# [Info] Final Vobs:  103.963
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m48_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 48 procesado con éxito.
#
#  Procesando orden 51...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.50
# [Info] Best template chisquare:  0.0056337372940070555
# [Info] ccf Vobs:  103.950
# [Info] Final Vobs:  103.954
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m51_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 51 procesado con éxito.
#
#  Procesando orden 52...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  104.00
# [Info] Best template chisquare:  0.0015026527115375072
# [Info] ccf Vobs:  103.350
# [Info] Final Vobs:  103.483
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m52_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 52 procesado con éxito.
#
#  Procesando orden 53...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.50
# [Info] Best template chisquare:  0.006908699102134381
# [Info] ccf Vobs:  103.225
# [Info] Final Vobs:  103.219
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m53_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 53 procesado con éxito.
#
#  Procesando orden 54...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.00
# [Info] Best template chisquare:  0.0008868299661964502
# [Info] ccf Vobs:  103.275
# [Info] Final Vobs:  103.273
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m54_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 54 procesado con éxito.
#
#  Procesando orden 55...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  102.50
# [Info] Best template chisquare:  0.0007718458582630267
# [Info] ccf Vobs:  102.550
# [Info] Final Vobs:  102.555
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m55_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 55 procesado con éxito.
#
#  Procesando orden 56...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  102.00
# [Info] Best template chisquare:  0.0010689834511025413
# [Info] ccf Vobs:  102.000
# [Info] Final Vobs:  102.000
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m56_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 56 procesado con éxito.
#
#  Procesando orden 57...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  105.50
# [Info] Best template chisquare:  0.003045290232663625
# [Info] ccf Vobs:  105.125
# [Info] Final Vobs:  103.699
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m57_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star4/Gran1-star4_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 57 procesado con éxito.

# %%
#estrella 7
#carpeta = "/home/nacho/molecfit_test/ordenes_star7/"
carpeta = "/home/nacho/molecfit_test/mis_outputs_star7/"
#carpeta = "/home/nacho/molecfit_test/mis_outputsVAC_star7/"
#vacuum_a_air(carpeta)
cross_corr_apli(carpeta)
# Out:
#  Procesando orden 43...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  106.00
# [Info] Best template chisquare:  0.0007172690216059804
# [Info] ccf Vobs:  105.175
# [Info] Final Vobs:  105.501
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m43_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 43 procesado con éxito.
#
#  Procesando orden 44...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  106.00
# [Info] Best template chisquare:  0.0005360668672110507
# [Info] ccf Vobs:  105.925
# [Info] Final Vobs:  105.932
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m44_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 44 procesado con éxito.
#
#  Procesando orden 45...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  105.50
# [Info] Best template chisquare:  0.0005571841720254117
# [Info] ccf Vobs:  104.450
# [Info] Final Vobs:  104.439
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m45_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 45 procesado con éxito.
#
#  Procesando orden 46...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  106.50
# [Info] Best template chisquare:  0.0007521794485929287
# [Info] ccf Vobs:  107.100
# [Info] Final Vobs:  106.689
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m46_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 46 procesado con éxito.
#
#  Procesando orden 47...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.50
# [Info] Best template chisquare:  0.0005404272258333793
# [Info] ccf Vobs:  104.025
# [Info] Final Vobs:  104.029
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m47_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 47 procesado con éxito.
#
#  Procesando orden 48...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  105.50
# [Info] Best template chisquare:  0.008152315490131984
# [Info] ccf Vobs:  105.500
# [Info] Final Vobs:  105.488
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m48_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 48 procesado con éxito.
#
#  Procesando orden 51...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  104.50
# [Info] Best template chisquare:  0.002107250258847979
# [Info] ccf Vobs:  104.675
# [Info] Final Vobs:  104.675
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m51_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 51 procesado con éxito.
#
#  Procesando orden 52...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  105.00
# [Info] Best template chisquare:  0.0009276971595977455
# [Info] ccf Vobs:  104.450
# [Info] Final Vobs:  104.451
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m52_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 52 procesado con éxito.
#
#  Procesando orden 53...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  104.50
# [Info] Best template chisquare:  0.0003514628312058048
# [Info] ccf Vobs:  104.325
# [Info] Final Vobs:  104.441
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m53_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 53 procesado con éxito.
#
#  Procesando orden 54...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  104.00
# [Info] Best template chisquare:  0.0003412983155912015
# [Info] ccf Vobs:  104.425
# [Info] Final Vobs:  104.248
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m54_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 54 procesado con éxito.
#
#  Procesando orden 55...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.50
# [Info] Best template chisquare:  0.00036182591944319056
# [Info] ccf Vobs:  104.525
# [Info] Final Vobs:  104.038
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m55_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 55 procesado con éxito.
#
#  Procesando orden 56...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.50
# [Info] Best template chisquare:  0.0004937923503740934
# [Info] ccf Vobs:  103.600
# [Info] Final Vobs:  103.598
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m56_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 56 procesado con éxito.
#
#  Procesando orden 57...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  106.00
# [Info] Best template chisquare:  0.0016502654259018062
# [Info] ccf Vobs:  105.700
# [Info] Final Vobs:  105.691
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m57_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star7/Gran1-star7_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 57 procesado con éxito.

# %%
#espectro = "/home/nacho/molecfit_test/mis_outputsVAC_star7/Gran1-star7_sum_m53_fsr1.05_VAC_modificado.par_tac.fits"
#solo_1_espectro(espectro)

# %%
#estrella 8
#carpeta = "/home/nacho/molecfit_test/ordenes_star8/"
carpeta = "/home/nacho/molecfit_test/mis_outputs_star8/"
#carpeta = "/home/nacho/molecfit_test/mis_outputsVAC_star8/"
#vacuum_a_air(carpeta)
cross_corr_apli(carpeta)
# Out:
#  Procesando orden 43...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  117.00
# [Info] Best template chisquare:  0.0012018908182481996
# [Info] ccf Vobs:  116.500
# [Info] Final Vobs:  116.494
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m43_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 43 procesado con éxito.
#
#  Procesando orden 44...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  116.00
# [Info] Best template chisquare:  0.0009971308890094272
# [Info] ccf Vobs:  115.825
# [Info] Final Vobs:  115.817
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m44_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 44 procesado con éxito.
#
#  Procesando orden 45...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  116.00
# [Info] Best template chisquare:  0.0008869089952560306
# [Info] ccf Vobs:  114.625
# [Info] Final Vobs:  114.624
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m45_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 45 procesado con éxito.
#
#  Procesando orden 46...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  117.50
# [Info] Best template chisquare:  0.00045860446715541466
# [Info] ccf Vobs:  116.450
# [Info] Final Vobs:  116.801
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m46_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 46 procesado con éxito.
#
#  Procesando orden 47...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  116.00
# [Info] Best template chisquare:  0.0008148847915303831
# [Info] ccf Vobs:  115.850
# [Info] Final Vobs:  115.843
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m47_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 47 procesado con éxito.
#
#  Procesando orden 48...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  116.50
# [Info] Best template chisquare:  0.01906028041415141
# [Info] ccf Vobs:  116.225
# [Info] Final Vobs:  116.222
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m48_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 48 procesado con éxito.
#
#  Procesando orden 51...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  113.50
# [Info] Best template chisquare:  0.0024960260880696828
# [Info] ccf Vobs:  114.975
# [Info] Final Vobs:  114.972
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m51_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 51 procesado con éxito.
#
#  Procesando orden 52...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  115.50
# [Info] Best template chisquare:  0.001038392755303354
# [Info] ccf Vobs:  116.000
# [Info] Final Vobs:  115.998
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m52_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 52 procesado con éxito.
#
#  Procesando orden 53...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  116.00
# [Info] Best template chisquare:  0.000622408489747754
# [Info] ccf Vobs:  115.800
# [Info] Final Vobs:  115.997
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m53_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 53 procesado con éxito.
#
#  Procesando orden 54...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  116.00
# [Info] Best template chisquare:  0.0006047312171851777
# [Info] ccf Vobs:  116.200
# [Info] Final Vobs:  116.190
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m54_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 54 procesado con éxito.
#
#  Procesando orden 55...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  115.50
# [Info] Best template chisquare:  0.0006188976538127272
# [Info] ccf Vobs:  115.425
# [Info] Final Vobs:  115.436
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m55_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 55 procesado con éxito.
#
#  Procesando orden 56...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  115.00
# [Info] Best template chisquare:  0.0008200556674996897
# [Info] ccf Vobs:  114.275
# [Info] Final Vobs:  114.911
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m56_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 56 procesado con éxito.
#
#  Procesando orden 57...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  115.50
# [Info] Best template chisquare:  0.0029233213105518394
# [Info] ccf Vobs:  115.200
# [Info] Final Vobs:  115.202
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m57_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star8/Gran01-star8_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 57 procesado con éxito.

# %%
#estrella 9
#carpeta = "/home/nacho/molecfit_test/ordenes_star9/"
carpeta = "/home/nacho/molecfit_test/mis_outputs_star9/"
#carpeta = "/home/nacho/molecfit_test/mis_outputsVAC_star9/"
#vacuum_a_air(carpeta)
cross_corr_apli(carpeta)
# Out:
#  Procesando orden 43...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  102.50
# [Info] Best template chisquare:  0.0011961946788499388
# [Info] ccf Vobs:  102.800
# [Info] Final Vobs:  102.798
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m43_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 43 procesado con éxito.
#
#  Procesando orden 44...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.00
# [Info] Best template chisquare:  0.0008330114158928769
# [Info] ccf Vobs:  103.350
# [Info] Final Vobs:  103.364
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m44_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 44 procesado con éxito.
#
#  Procesando orden 45...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  102.00
# [Info] Best template chisquare:  0.0003889127011929709
# [Info] ccf Vobs:  102.000
# [Info] Final Vobs:  102.009
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m45_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 45 procesado con éxito.
#
#  Procesando orden 46...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.00
# [Info] Best template chisquare:  0.00042938835503344134
# [Info] ccf Vobs:  102.650
# [Info] Final Vobs:  102.644
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m46_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 46 procesado con éxito.
#
#  Procesando orden 47...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  101.00
# [Info] Best template chisquare:  0.0007526083600335267
# [Info] ccf Vobs:  101.975
# [Info] Final Vobs:  101.918
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m47_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 47 procesado con éxito.
#
#  Procesando orden 48...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.00
# [Info] Best template chisquare:  0.0009401623175295475
# [Info] ccf Vobs:  102.700
# [Info] Final Vobs:  102.698
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m48_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 48 procesado con éxito.
#
#  Procesando orden 51...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  102.00
# [Info] Best template chisquare:  0.004978576620633937
# [Info] ccf Vobs:  101.875
# [Info] Final Vobs:  102.207
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m51_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 51 procesado con éxito.
#
#  Procesando orden 52...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  101.50
# [Info] Best template chisquare:  0.0010173444093096846
# [Info] ccf Vobs:  101.775
# [Info] Final Vobs:  101.779
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m52_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 52 procesado con éxito.
#
#  Procesando orden 53...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  102.00
# [Info] Best template chisquare:  0.0014042992034576497
# [Info] ccf Vobs:  101.850
# [Info] Final Vobs:  101.841
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m53_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 53 procesado con éxito.
#
#  Procesando orden 54...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  102.00
# [Info] Best template chisquare:  0.0006057776006513212
# [Info] ccf Vobs:  102.125
# [Info] Final Vobs:  102.138
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m54_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 54 procesado con éxito.
#
#  Procesando orden 55...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  101.50
# [Info] Best template chisquare:  0.0005726666428743978
# [Info] ccf Vobs:  101.075
# [Info] Final Vobs:  101.524
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m55_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 55 procesado con éxito.
#
#  Procesando orden 56...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  100.50
# [Info] Best template chisquare:  0.0006537557394909998
# [Info] ccf Vobs:  102.000
# [Info] Final Vobs:  100.556
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m56_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 56 procesado con éxito.
#
#  Procesando orden 57...
# [Info] Number of templates:  215
# [Info] Inputs allow to compute velocity shifts in(   50.00,  150.00)
# [Info] Preliminary Vobs:  103.50
# [Info] Best template chisquare:  0.0022335344219226627
# [Info] ccf Vobs:  103.475
# [Info] Final Vobs:  102.081
# [Info] Corrected spectrum written in:  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m57_fsr1.05_AIR_modificado.par_tac_vcorr.fits
# [Info] Results written in  /home/nacho/molecfit_test/mis_outputs_star9/Gran1-star9_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#
# Orden 57 procesado con éxito.

# %% [markdown]
# # ahora vamos a buscar las velocidades radiales en los archivos

# %%
import os

# Carpetas donde se encuentran los outputs de rvcorr_fitsTableSpec
carpetas = [
    "/home/nacho/molecfit_test/mis_outputs_star1/",
    "/home/nacho/molecfit_test/mis_outputs_star3/",
    "/home/nacho/molecfit_test/mis_outputs_star4/",
    "/home/nacho/molecfit_test/mis_outputs_star7/",
    "/home/nacho/molecfit_test/mis_outputs_star8/",
    "/home/nacho/molecfit_test/mis_outputs_star9/"]
# carpetas = [
#     "/home/nacho/molecfit_test/mis_outputsVAC_star1//",
#     "/home/nacho/molecfit_test/mis_outputsVAC_star3/",
#     "/home/nacho/molecfit_test/mis_outputsVAC_star4/",
#     "/home/nacho/molecfit_test/mis_outputsVAC_star7/",
#     "/home/nacho/molecfit_test/mis_outputsVAC_star8/",
#     "/home/nacho/molecfit_test/mis_outputsVAC_star9/"
#]
# carpetas = [
#     "/home/nacho/molecfit_test/ordenes_star1/",
#     "/home/nacho/molecfit_test/ordenes_star3/",
#     "/home/nacho/molecfit_test/ordenes_star4/",
#     "/home/nacho/molecfit_test/ordenes_star7/",
#     "/home/nacho/molecfit_test/ordenes_star8/",
#     "/home/nacho/molecfit_test/ordenes_star9/"
# ]
for carpeta in carpetas:
    print("\n Revisando:", carpeta)
    for root, dirs, files in os.walk(carpeta):
        for f in files:
            if f.lower().endswith(".dat"):
                print("   ", f)
def extraer_rvs(carpeta):
    import os
    import glob
    import numpy as np

    # Buscar archivos .dat dentro de la carpeta
    archivos = sorted(glob.glob(os.path.join(carpeta, "**", "*VAC_modificado.par_tac_RV.dat"), recursive=True))# par_tac_RV.dat AIR_RV.dat

    if not archivos:
        print(f" No se encontraron archivos .dat en {carpeta}")
        return []

    rvs = []
    for ruta in archivos:
        with open(ruta, "r") as f:
            for linea in f:
                linea = linea.strip()
                if not linea or linea.startswith("#"):
                    continue
                partes = linea.split()
                if len(partes) > 1:
                    try:
                        rv = float(partes[1])  # segundo dato numérico
                        rvs.append(rv)
                    except ValueError:
                        continue  # ignora líneas no numéricas
    print(f"{os.path.basename(os.path.normpath(carpeta))}: {len(rvs)} valores leidos ")
    print(f"{os.path.basename(os.path.normpath(carpeta))}: la deviacion estandar es: {np.std(rvs)}")
    return rvs

# Procesar todas las carpetas
rvs = []

for c in carpetas:
    rvs.append(extraer_rvs(c))
# Out:
#  Revisando: /home/nacho/molecfit_test/mis_outputs_star1/
#     Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#
#  Revisando: /home/nacho/molecfit_test/mis_outputs_star3/
#     Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star3_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star3_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#
#  Revisando: /home/nacho/molecfit_test/mis_outputs_star4/
#     Gran1-star4_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star4_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star4_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#
#  Revisando: /home/nacho/molecfit_test/mis_outputs_star7/
#     Gran1-star7_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star7_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star7_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#
#  Revisando: /home/nacho/molecfit_test/mis_outputs_star8/
#     Gran01-star8_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran01-star8_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran01-star8_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#
#  Revisando: /home/nacho/molecfit_test/mis_outputs_star9/
#     Gran1-star9_sum_m43_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m44_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m45_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m46_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m47_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m48_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m51_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m52_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m53_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m54_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m55_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m56_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m57_fsr1.05_AIR_modificado.par_tac_RV.dat
#     Gran1-star9_sum_m43_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m44_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m45_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m46_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m47_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m48_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m51_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m52_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m53_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m54_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m55_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m56_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#     Gran1-star9_sum_m57_fsr1.05_AIR_modificado.par_tac_backup_vacuum_RV.dat
#  No se encontraron archivos .dat en /home/nacho/molecfit_test/mis_outputs_star1/
#  No se encontraron archivos .dat en /home/nacho/molecfit_test/mis_outputs_star3/
#  No se encontraron archivos .dat en /home/nacho/molecfit_test/mis_outputs_star4/
#  No se encontraron archivos .dat en /home/nacho/molecfit_test/mis_outputs_star7/
#  No se encontraron archivos .dat en /home/nacho/molecfit_test/mis_outputs_star8/
#  No se encontraron archivos .dat en /home/nacho/molecfit_test/mis_outputs_star9/

# %%
import numpy as np
# car1 = "/home/nacho/molecfit_test/mis_outputs_star1/"
# car3 = "/home/nacho/molecfit_test/mis_outputs_star3/"
# car4 = "/home/nacho/molecfit_test/mis_outputs_star4/"
# car7 = "/home/nacho/molecfit_test/mis_outputs_star7/"
# car8 = "/home/nacho/molecfit_test/mis_outputs_star8/"
# car9 = "/home/nacho/molecfit_test/mis_outputs_star9/"
car1 = "/home/nacho/molecfit_test/mis_outputsVAC_star1/"
car3 = "/home/nacho/molecfit_test/mis_outputsVAC_star3/"
car4 = "/home/nacho/molecfit_test/mis_outputsVAC_star4/"
car7 = "/home/nacho/molecfit_test/mis_outputsVAC_star7/"
car8 = "/home/nacho/molecfit_test/mis_outputsVAC_star8/"
car9 = "/home/nacho/molecfit_test/mis_outputsVAC_star9/"
# car1 = "/home/nacho/molecfit_test/ordenes_star1/"
# car3 = "/home/nacho/molecfit_test/ordenes_star3/"
# car4 = "/home/nacho/molecfit_test/ordenes_star4/"
# car7 = "/home/nacho/molecfit_test/ordenes_star7/"
# car8 = "/home/nacho/molecfit_test/ordenes_star8/"
# car9 = "/home/nacho/molecfit_test/ordenes_star1/"
rbcs=[baric_corr(car1),baric_corr(car3),baric_corr(car4),baric_corr(car7),baric_corr(car8),baric_corr(car9)]

rvs_final = []
print(f"las velocidades baricentricas son: {rbcs}")
xd = 0
while xd < 6:
    print(f"velocidad radial estrella {xd} = {np.median(rvs[xd])+rbcs[xd]} km/s")
    rvs_final.append(np.median(rvs[xd])+rbcs[xd])
    xd += 1
# Out:
# no se encontraron archivos en: /home/nacho/molecfit_test/mis_outputsVAC_star1/
# no se encontraron archivos en: /home/nacho/molecfit_test/mis_outputsVAC_star3/
# no se encontraron archivos en: /home/nacho/molecfit_test/mis_outputsVAC_star4/
# no se encontraron archivos en: /home/nacho/molecfit_test/mis_outputsVAC_star7/
# no se encontraron archivos en: /home/nacho/molecfit_test/mis_outputsVAC_star8/
# no se encontraron archivos en: /home/nacho/molecfit_test/mis_outputsVAC_star9/
# las velocidades baricentricas son: [None, None, None, None, None, None]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 26
#      24 xd = 0
#      25 while xd < 6:
# ---> 26     print(f"velocidad radial estrella {xd} = {np.median(rvs[xd])+rbcs[xd]} km/s")
#      27     rvs_final.append(np.median(rvs[xd])+rbcs[xd])
#      28     xd += 1
#
# TypeError: unsupported operand type(s) for +: 'float' and 'NoneType'

# %%
# rvs = [113,116,104,105,116,103]
# rvs_ff = []
# a = 0
# while a<6:
#     rvs_ff.append(rvs[a]+rvs_final[a])
#     a +=1
# rvs_ff
